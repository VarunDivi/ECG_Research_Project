# %% [markdown]
# ### Imports

# %%
import tensorflow as tf # Models ran in venv python 3.9.16 with GPU computing support
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wfdb
import ast
import ecg_plot
import xgboost as xgb 
import tensorflow as tf # Models ran in venv python 3.9.16 with GPU computing support
import os
import scipy.io as sio

# %% [markdown]
# ### PTB-XL Loading

# %%
sr = 100
quick_load = False
load_model = True
save_model = False

# %%
with tf.device('/CPU:0'):
    ### Loading raw data into mutable Datframes
    def load_data():
        ptb = pd.read_csv('../data/PTBXL/ptbxl_database.csv')
        def load_raw_data(df, sampling_rate, path):
            if(sampling_rate == 100):
                data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
            else:
                data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
            data = np.array([signal for signal, meta in data])
            return data
        
        # load and convert annotation data
        Y = pd.read_csv('../data/PTBXL/ptbxl_database.csv', index_col='ecg_id')
        Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

        # Load raw signal data
        X = load_raw_data(Y, sr, '../data/PTBXL/')

        # Load scp_statements.csv for diagnostic aggregation
        agg_df = pd.read_csv('../data/PTBXL/scp_statements.csv', index_col=0)
        agg_df = agg_df[agg_df.diagnostic == 1]

        def aggregate_diagnostic(y_dic):
            tmp = []
            for key in y_dic.keys():
                if key in agg_df.index:
                    tmp.append(agg_df.loc[key].diagnostic_class)
            return list(set(tmp))


        # Apply diagnostic superclass
        Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)
    
        return X,Y


if(quick_load):
    X_xl = np.load('../data/PTBXL/X_raw.npy')
    Y_xl = pd.read_csv('../data/PTBXL/Y_raw.csv')
    Y_xlPlus = pd.read_csv('../data/PTBXLPlus/Y_rawPlus.csv')
else:
    X_xl,Y_xl = load_data()

# %% [markdown]
# ### PTB-XL+ Loading

# %%
with tf.device('/CPU:0'):
    def load_delifeatures():
        # Load Deli features
        deli_csv = pd.read_csv('../data/PTBXLPlus/ecgdeli_features.csv')

        return deli_csv

deli_csv = load_delifeatures()

# %%
Y = deli_csv.join(Y_xl, on='ecg_id', how='inner')

# %%
Y.columns.to_list()
# Out:
# ['ecg_id',
#  'PQ_Int_I',
#  'PQ_Int_I_iqr',
#  'PQ_Int_I_count',
#  'PQ_Int_II',
#  'PQ_Int_II_iqr',
#  'PQ_Int_II_count',
#  'PQ_Int_III',
#  'PQ_Int_III_iqr',
#  'PQ_Int_III_count',
#  'PQ_Int_V1',
#  'PQ_Int_V1_iqr',
#  'PQ_Int_V1_count',
#  'PQ_Int_V2',
#  'PQ_Int_V2_iqr',
#  'PQ_Int_V2_count',
#  'PQ_Int_V3',
#  'PQ_Int_V3_iqr',
#  'PQ_Int_V3_count',
#  'PQ_Int_V4',
#  'PQ_Int_V4_iqr',
#  'PQ_Int_V4_count',
#  'PQ_Int_V5',
#  'PQ_Int_V5_iqr',
#  'PQ_Int_V5_count',
#  'PQ_Int_V6',
#  'PQ_Int_V6_iqr',
#  'PQ_Int_V6_count',
#  'PQ_Int_aVF',
#  'PQ_Int_aVF_iqr',
#  'PQ_Int_aVF_count',
#  'PQ_Int_aVL',
#  'PQ_Int_aVL_iqr',
#  'PQ_Int_aVL_count',
#  'PQ_Int_aVR',
#  'PQ_Int_aVR_iqr',
#  'PQ_Int_aVR_count',
#  'PQ_Int_Global',
#  'PQ_Int_Global_iqr',
#  'PQ_Int_Global_count',
#  'PR_Int_I',
#  'PR_Int_I_iqr',
#  'PR_Int_I_count',
#  'PR_Int_II',
#  'PR_Int_II_iqr',
#  'PR_Int_II_count',
#  'PR_Int_III',
#  'PR_Int_III_iqr',
#  'PR_Int_III_count',
#  'PR_Int_V1',
#  'PR_Int_V1_iqr',
#  'PR_Int_V1_count',
#  'PR_Int_V2',
#  'PR_Int_V2_iqr',
#  'PR_Int_V2_count',
#  'PR_Int_V3',
#  'PR_Int_V3_iqr',
#  'PR_Int_V3_count',
#  'PR_Int_V4',
#  'PR_Int_V4_iqr',
#  'PR_Int_V4_count',
#  'PR_Int_V5',
#  'PR_Int_V5_iqr',
#  'PR_Int_V5_count',
#  'PR_Int_V6',
#  'PR_Int_V6_iqr',
#  'PR_Int_V6_count',
#  'PR_Int_aVF',
#  'PR_Int_aVF_iqr',
#  'PR_Int_aVF_count',
#  'PR_Int_aVL',
#  'PR_Int_aVL_iqr',
#  'PR_Int_aVL_count',
#  'PR_Int_aVR',
#  'PR_Int_aVR_iqr',
#  'PR_Int_aVR_count',
#  'PR_Int_Global',
#  'PR_Int_Global_iqr',
#  'PR_Int_Global_count',
#  'P_Amp_I',
#  'P_Amp_I_iqr',
#  'P_Amp_I_count',
#  'P_Amp_II',
#  'P_Amp_II_iqr',
#  'P_Amp_II_count',
#  'P_Amp_III',
#  'P_Amp_III_iqr',
#  'P_Amp_III_count',
#  'P_Amp_V1',
#  'P_Amp_V1_iqr',
#  'P_Amp_V1_count',
#  'P_Amp_V2',
#  'P_Amp_V2_iqr',
#  'P_Amp_V2_count',
#  'P_Amp_V3',
#  'P_Amp_V3_iqr',
#  'P_Amp_V3_count',
#  'P_Amp_V4',
#  'P_Amp_V4_iqr',
#  'P_Amp_V4_count',
#  'P_Amp_V5',
#  'P_Amp_V5_iqr',
#  'P_Amp_V5_count',
#  'P_Amp_V6',
#  'P_Amp_V6_iqr',
#  'P_Amp_V6_count',
#  'P_Amp_aVF',
#  'P_Amp_aVF_iqr',
#  'P_Amp_aVF_count',
#  'P_Amp_aVL',
#  'P_Amp_aVL_iqr',
#  'P_Amp_aVL_count',
#  'P_Amp_aVR',
#  'P_Amp_aVR_iqr',
#  'P_Amp_aVR_count',
#  'P_DurFull_I',
#  'P_DurFull_I_iqr',
#  'P_DurFull_I_count',
#  'P_DurFull_II',
#  'P_DurFull_II_iqr',
#  'P_DurFull_II_count',
#  'P_DurFull_III',
#  'P_DurFull_III_iqr',
#  'P_DurFull_III_count',
#  'P_DurFull_V1',
#  'P_DurFull_V1_iqr',
#  'P_DurFull_V1_count',
#  'P_DurFull_V2',
#  'P_DurFull_V2_iqr',
#  'P_DurFull_V2_count',
#  'P_DurFull_V3',
#  'P_DurFull_V3_iqr',
#  'P_DurFull_V3_count',
#  'P_DurFull_V4',
#  'P_DurFull_V4_iqr',
#  'P_DurFull_V4_count',
#  'P_DurFull_V5',
#  'P_DurFull_V5_iqr',
#  'P_DurFull_V5_count',
#  'P_DurFull_V6',
#  'P_DurFull_V6_iqr',
#  'P_DurFull_V6_count',
#  'P_DurFull_aVF',
#  'P_DurFull_aVF_iqr',
#  'P_DurFull_aVF_count',
#  'P_DurFull_aVL',
#  'P_DurFull_aVL_iqr',
#  'P_DurFull_aVL_count',
#  'P_DurFull_aVR',
#  'P_DurFull_aVR_iqr',
#  'P_DurFull_aVR_count',
#  'P_Dur_Global',
#  'P_Dur_Global_iqr',
#  'P_Dur_Global_count',
#  'P_Morph_I',
#  'P_Morph_I_iqr',
#  'P_Morph_I_count',
#  'P_Morph_II',
#  'P_Morph_II_iqr',
#  'P_Morph_II_count',
#  'P_Morph_III',
#  'P_Morph_III_iqr',
#  'P_Morph_III_count',
#  'P_Morph_V1',
#  'P_Morph_V1_iqr',
#  'P_Morph_V1_count',
#  'P_Morph_V2',
#  'P_Morph_V2_iqr',
#  'P_Morph_V2_count',
#  'P_Morph_V3',
#  'P_Morph_V3_iqr',
#  'P_Morph_V3_count',
#  'P_Morph_V4',
#  'P_Morph_V4_iqr',
#  'P_Morph_V4_count',
#  'P_Morph_V5',
#  'P_Morph_V5_iqr',
#  'P_Morph_V5_count',
#  'P_Morph_V6',
#  'P_Morph_V6_iqr',
#  'P_Morph_V6_count',
#  'P_Morph_aVF',
#  'P_Morph_aVF_iqr',
#  'P_Morph_aVF_count',
#  'P_Morph_aVL',
#  'P_Morph_aVL_iqr',
#  'P_Morph_aVL_count',
#  'P_Morph_aVR',
#  'P_Morph_aVR_iqr',
#  'P_Morph_aVR_count',
#  'Q_Amp_I',
#  'Q_Amp_I_iqr',
#  'Q_Amp_I_count',
#  'Q_Amp_II',
#  'Q_Amp_II_iqr',
#  'Q_Amp_II_count',
#  'Q_Amp_III',
#  'Q_Amp_III_iqr',
#  'Q_Amp_III_count',
#  'Q_Amp_V1',
#  'Q_Amp_V1_iqr',
#  'Q_Amp_V1_count',
#  'Q_Amp_V2',
#  'Q_Amp_V2_iqr',
#  'Q_Amp_V2_count',
#  'Q_Amp_V3',
#  'Q_Amp_V3_iqr',
#  'Q_Amp_V3_count',
#  'Q_Amp_V4',
#  'Q_Amp_V4_iqr',
#  'Q_Amp_V4_count',
#  'Q_Amp_V5',
#  'Q_Amp_V5_iqr',
#  'Q_Amp_V5_count',
#  'Q_Amp_V6',
#  'Q_Amp_V6_iqr',
#  'Q_Amp_V6_count',
#  'Q_Amp_aVF',
#  'Q_Amp_aVF_iqr',
#  'Q_Amp_aVF_count',
#  'Q_Amp_aVL',
#  'Q_Amp_aVL_iqr',
#  'Q_Amp_aVL_count',
#  'Q_Amp_aVR',
#  'Q_Amp_aVR_iqr',
#  'Q_Amp_aVR_count',
#  'QRS_Dur_I',
#  'QRS_Dur_I_iqr',
#  'QRS_Dur_I_count',
#  'QRS_Dur_II',
#  'QRS_Dur_II_iqr',
#  'QRS_Dur_II_count',
#  'QRS_Dur_III',
#  'QRS_Dur_III_iqr',
#  'QRS_Dur_III_count',
#  'QRS_Dur_V1',
#  'QRS_Dur_V1_iqr',
#  'QRS_Dur_V1_count',
#  'QRS_Dur_V2',
#  'QRS_Dur_V2_iqr',
#  'QRS_Dur_V2_count',
#  'QRS_Dur_V3',
#  'QRS_Dur_V3_iqr',
#  'QRS_Dur_V3_count',
#  'QRS_Dur_V4',
#  'QRS_Dur_V4_iqr',
#  'QRS_Dur_V4_count',
#  'QRS_Dur_V5',
#  'QRS_Dur_V5_iqr',
#  'QRS_Dur_V5_count',
#  'QRS_Dur_V6',
#  'QRS_Dur_V6_iqr',
#  'QRS_Dur_V6_count',
#  'QRS_Dur_aVF',
#  'QRS_Dur_aVF_iqr',
#  'QRS_Dur_aVF_count',
#  'QRS_Dur_aVL',
#  'QRS_Dur_aVL_iqr',
#  'QRS_Dur_aVL_count',
#  'QRS_Dur_aVR',
#  'QRS_Dur_aVR_iqr',
#  'QRS_Dur_aVR_count',
#  'QRS_Dur_Global',
#  'QRS_Dur_Global_iqr',
#  'QRS_Dur_Global_count',
#  'QT_IntCorr_I',
#  'QT_IntCorr_I_iqr',
#  'QT_IntCorr_I_count',
#  'QT_IntCorr_II',
#  'QT_IntCorr_II_iqr',
#  'QT_IntCorr_II_count',
#  'QT_IntCorr_III',
#  'QT_IntCorr_III_iqr',
#  'QT_IntCorr_III_count',
#  'QT_IntCorr_V1',
#  'QT_IntCorr_V1_iqr',
#  'QT_IntCorr_V1_count',
#  'QT_IntCorr_V2',
#  'QT_IntCorr_V2_iqr',
#  'QT_IntCorr_V2_count',
#  'QT_IntCorr_V3',
#  'QT_IntCorr_V3_iqr',
#  'QT_IntCorr_V3_count',
#  'QT_IntCorr_V4',
#  'QT_IntCorr_V4_iqr',
#  'QT_IntCorr_V4_count',
#  'QT_IntCorr_V5',
#  'QT_IntCorr_V5_iqr',
#  'QT_IntCorr_V5_count',
#  'QT_IntCorr_V6',
#  'QT_IntCorr_V6_iqr',
#  'QT_IntCorr_V6_count',
#  'QT_IntCorr_aVF',
#  'QT_IntCorr_aVF_iqr',
#  'QT_IntCorr_aVF_count',
#  'QT_IntCorr_aVL',
#  'QT_IntCorr_aVL_iqr',
#  'QT_IntCorr_aVL_count',
#  'QT_IntCorr_aVR',
#  'QT_IntCorr_aVR_iqr',
#  'QT_IntCorr_aVR_count',
#  'QT_IntFramingham_Global',
#  'QT_IntFramingham_Global_iqr',
#  'QT_IntFramingham_Global_count',
#  'QT_Int_I',
#  'QT_Int_I_iqr',
#  'QT_Int_I_count',
#  'QT_Int_II',
#  'QT_Int_II_iqr',
#  'QT_Int_II_count',
#  'QT_Int_III',
#  'QT_Int_III_iqr',
#  'QT_Int_III_count',
#  'QT_Int_V1',
#  'QT_Int_V1_iqr',
#  'QT_Int_V1_count',
#  'QT_Int_V2',
#  'QT_Int_V2_iqr',
#  'QT_Int_V2_count',
#  'QT_Int_V3',
#  'QT_Int_V3_iqr',
#  'QT_Int_V3_count',
#  'QT_Int_V4',
#  'QT_Int_V4_iqr',
#  'QT_Int_V4_count',
#  'QT_Int_V5',
#  'QT_Int_V5_iqr',
#  'QT_Int_V5_count',
#  'QT_Int_V6',
#  'QT_Int_V6_iqr',
#  'QT_Int_V6_count',
#  'QT_Int_aVF',
#  'QT_Int_aVF_iqr',
#  'QT_Int_aVF_count',
#  'QT_Int_aVL',
#  'QT_Int_aVL_iqr',
#  'QT_Int_aVL_count',
#  'QT_Int_aVR',
#  'QT_Int_aVR_iqr',
#  'QT_Int_aVR_count',
#  'QT_Int_Global',
#  'QT_Int_Global_iqr',
#  'QT_Int_Global_count',
#  'R_Amp_I',
#  'R_Amp_I_iqr',
#  'R_Amp_I_count',
#  'R_Amp_II',
#  'R_Amp_II_iqr',
#  'R_Amp_II_count',
#  'R_Amp_III',
#  'R_Amp_III_iqr',
#  'R_Amp_III_count',
#  'R_Amp_V1',
#  'R_Amp_V1_iqr',
#  'R_Amp_V1_count',
#  'R_Amp_V2',
#  'R_Amp_V2_iqr',
#  'R_Amp_V2_count',
#  'R_Amp_V3',
#  'R_Amp_V3_iqr',
#  'R_Amp_V3_count',
#  'R_Amp_V4',
#  'R_Amp_V4_iqr',
#  'R_Amp_V4_count',
#  'R_Amp_V5',
#  'R_Amp_V5_iqr',
#  'R_Amp_V5_count',
#  'R_Amp_V6',
#  'R_Amp_V6_iqr',
#  'R_Amp_V6_count',
#  'R_Amp_aVF',
#  'R_Amp_aVF_iqr',
#  'R_Amp_aVF_count',
#  'R_Amp_aVL',
#  'R_Amp_aVL_iqr',
#  'R_Amp_aVL_count',
#  'R_Amp_aVR',
#  'R_Amp_aVR_iqr',
#  'R_Amp_aVR_count',
#  'RR_Mean_Global',
#  'RR_Mean_Global_iqr',
#  'RR_Mean_Global_count',
#  'S_Amp_I',
#  'S_Amp_I_iqr',
#  'S_Amp_I_count',
#  'S_Amp_II',
#  'S_Amp_II_iqr',
#  'S_Amp_II_count',
#  'S_Amp_III',
#  'S_Amp_III_iqr',
#  'S_Amp_III_count',
#  'S_Amp_V1',
#  'S_Amp_V1_iqr',
#  'S_Amp_V1_count',
#  'S_Amp_V2',
#  'S_Amp_V2_iqr',
#  'S_Amp_V2_count',
#  'S_Amp_V3',
#  'S_Amp_V3_iqr',
#  'S_Amp_V3_count',
#  'S_Amp_V4',
#  'S_Amp_V4_iqr',
#  'S_Amp_V4_count',
#  'S_Amp_V5',
#  'S_Amp_V5_iqr',
#  'S_Amp_V5_count',
#  'S_Amp_V6',
#  'S_Amp_V6_iqr',
#  'S_Amp_V6_count',
#  'S_Amp_aVF',
#  'S_Amp_aVF_iqr',
#  'S_Amp_aVF_count',
#  'S_Amp_aVL',
#  'S_Amp_aVL_iqr',
#  'S_Amp_aVL_count',
#  'S_Amp_aVR',
#  'S_Amp_aVR_iqr',
#  'S_Amp_aVR_count',
#  'ST_Elev_I',
#  'ST_Elev_I_iqr',
#  'ST_Elev_I_count',
#  'ST_Elev_II',
#  'ST_Elev_II_iqr',
#  'ST_Elev_II_count',
#  'ST_Elev_III',
#  'ST_Elev_III_iqr',
#  'ST_Elev_III_count',
#  'ST_Elev_V1',
#  'ST_Elev_V1_iqr',
#  'ST_Elev_V1_count',
#  'ST_Elev_V2',
#  'ST_Elev_V2_iqr',
#  'ST_Elev_V2_count',
#  'ST_Elev_V3',
#  'ST_Elev_V3_iqr',
#  'ST_Elev_V3_count',
#  'ST_Elev_V4',
#  'ST_Elev_V4_iqr',
#  'ST_Elev_V4_count',
#  'ST_Elev_V5',
#  'ST_Elev_V5_iqr',
#  'ST_Elev_V5_count',
#  'ST_Elev_V6',
#  'ST_Elev_V6_iqr',
#  'ST_Elev_V6_count',
#  'ST_Elev_aVF',
#  'ST_Elev_aVF_iqr',
#  'ST_Elev_aVF_count',
#  'ST_Elev_aVL',
#  'ST_Elev_aVL_iqr',
#  'ST_Elev_aVL_count',
#  'ST_Elev_aVR',
#  'ST_Elev_aVR_iqr',
#  'ST_Elev_aVR_count',
#  'T_Amp_I',
#  'T_Amp_I_iqr',
#  'T_Amp_I_count',
#  'T_Amp_II',
#  'T_Amp_II_iqr',
#  'T_Amp_II_count',
#  'T_Amp_III',
#  'T_Amp_III_iqr',
#  'T_Amp_III_count',
#  'T_Amp_V1',
#  'T_Amp_V1_iqr',
#  'T_Amp_V1_count',
#  'T_Amp_V2',
#  'T_Amp_V2_iqr',
#  'T_Amp_V2_count',
#  'T_Amp_V3',
#  'T_Amp_V3_iqr',
#  'T_Amp_V3_count',
#  'T_Amp_V4',
#  'T_Amp_V4_iqr',
#  'T_Amp_V4_count',
#  'T_Amp_V5',
#  'T_Amp_V5_iqr',
#  'T_Amp_V5_count',
#  'T_Amp_V6',
#  'T_Amp_V6_iqr',
#  'T_Amp_V6_count',
#  'T_Amp_aVF',
#  'T_Amp_aVF_iqr',
#  'T_Amp_aVF_count',
#  'T_Amp_aVL',
#  'T_Amp_aVL_iqr',
#  'T_Amp_aVL_count',
#  'T_Amp_aVR',
#  'T_Amp_aVR_iqr',
#  'T_Amp_aVR_count',
#  'T_DurFull_I',
#  'T_DurFull_I_iqr',
#  'T_DurFull_I_count',
#  'T_DurFull_II',
#  'T_DurFull_II_iqr',
#  'T_DurFull_II_count',
#  'T_DurFull_III',
#  'T_DurFull_III_iqr',
#  'T_DurFull_III_count',
#  'T_DurFull_V1',
#  'T_DurFull_V1_iqr',
#  'T_DurFull_V1_count',
#  'T_DurFull_V2',
#  'T_DurFull_V2_iqr',
#  'T_DurFull_V2_count',
#  'T_DurFull_V3',
#  'T_DurFull_V3_iqr',
#  'T_DurFull_V3_count',
#  'T_DurFull_V4',
#  'T_DurFull_V4_iqr',
#  'T_DurFull_V4_count',
#  'T_DurFull_V5',
#  'T_DurFull_V5_iqr',
#  'T_DurFull_V5_count',
#  'T_DurFull_V6',
#  'T_DurFull_V6_iqr',
#  'T_DurFull_V6_count',
#  'T_DurFull_aVF',
#  'T_DurFull_aVF_iqr',
#  'T_DurFull_aVF_count',
#  'T_DurFull_aVL',
#  'T_DurFull_aVL_iqr',
#  'T_DurFull_aVL_count',
#  'T_DurFull_aVR',
#  'T_DurFull_aVR_iqr',
#  'T_DurFull_aVR_count',
#  'T_Dur_Global',
#  'T_Dur_Global_iqr',
#  'T_Dur_Global_count',
#  'HA__Global',
#  'HA__Global_iqr',
#  'HA__Global_count',
#  'patient_id',
#  'age',
#  'sex',
#  'height',
#  'weight',
#  'nurse',
#  'site',
#  'device',
#  'recording_date',
#  'report',
#  'scp_codes',
#  'heart_axis',
#  'infarction_stadium1',
#  'infarction_stadium2',
#  'validated_by',
#  'second_opinion',
#  'initial_autogenerated_report',
#  'validated_by_human',
#  'baseline_drift',
#  'static_noise',
#  'burst_noise',
#  'electrodes_problems',
#  'extra_beats',
#  'pacemaker',
#  'strat_fold',
#  'filename_lr',
#  'filename_hr',
#  'diagnostic_superclass']

# %%
# Save Y as a csv
Y.to_csv('../data/PTBXLPlus/Y_rawPlus.csv', index=False)

# Load Y
Y = pd.read_csv('../data/PTBXLPlus/Y_rawPlus.csv')
