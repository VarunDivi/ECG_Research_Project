# %%
import tensorflow as tf # Models ran in venv python 3.9.16 with GPU computing support
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wfdb
import ast
import ecg_plot
import xgboost as xgb 
import tensorflow as tf # Models ran in venv python 3.9.16 with GPU computing support
import os
import scipy.io as sio

# %%
cnn_rnn_age_model = tf.keras.models.load_model('../saved_models/100hz/age_models/cnn_rnn_age_model_0.855')
disc_model_loaded = tf.keras.models.load_model('../saved_models/gans/discrminator_model')
gen_model_loaded = tf.keras.models.load_model('../saved_models/gans/generator_model')
cnn_rnn_sex_model = tf.keras.models.load_model('../saved_models/100hz/sex_models/rnn_sex_model_0.8310.h5')
# Out:
# C:\Users\varun\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\saving\saved_model\load.py:107: RuntimeWarning: Unexpected end-group tag: Not all data was converted
#   metadata.ParseFromString(file_content)

# %% [markdown]
# ## CNN and LSTM age Model Viz

# %%
cnn_rnn_age_model.summary()
plot_model(cnn_rnn_age_model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 249, 32)           3104
#
#  batch_normalization (BatchN  (None, 249, 32)          128
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 248, 32)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 81, 48)            9264
#
#  batch_normalization_1 (Batc  (None, 81, 48)           192
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 79, 48)           0
#  1D)
#
#  dropout (Dropout)           (None, 79, 48)            0
#
#  conv1d_2 (Conv1D)           (None, 38, 64)            12352
#
#  batch_normalization_2 (Batc  (None, 38, 64)           256
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 37, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 35, 96)            18528
#
#  batch_normalization_3 (Batc  (None, 35, 96)           384
#  hNormalization)
# ...

# %% [markdown]
# ## Discriminator Model View

# %%
disc_model_loaded.summary()
plot_model(disc_model_loaded, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  conv1d (Conv1D)                (None, 1000, 32)     384         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 1000, 12)     0           ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1000, 32)     40960       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1000, 32)     20480       ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 1000, 32)     10240       ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 1000, 32)     384         ['max_pooling1d[0][0]']
#
#  concatenate (Concatenate)      (None, 1000, 128)    0           ['conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]',
# ...

# %% [markdown]
# ## CNN and LSTM Sex Model Viz

# %%
cnn_rnn_sex_model.summary()
plot_model(cnn_rnn_sex_model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_112 (Conv1D)         (None, 249, 32)           3104
#
#  batch_normalization_56 (Bat  (None, 249, 32)          128
#  chNormalization)
#
#  max_pooling1d_112 (MaxPooli  (None, 248, 32)          0
#  ng1D)
#
#  conv1d_113 (Conv1D)         (None, 121, 64)           14400
#
#  batch_normalization_57 (Bat  (None, 121, 64)          256
#  chNormalization)
#
#  max_pooling1d_113 (MaxPooli  (None, 121, 64)          0
#  ng1D)
#
#  dropout_57 (Dropout)        (None, 121, 64)           0
#
#  conv1d_114 (Conv1D)         (None, 59, 96)            30816
#
#  batch_normalization_58 (Bat  (None, 59, 96)           384
#  chNormalization)
#
#  max_pooling1d_114 (MaxPooli  (None, 58, 96)           0
#  ng1D)
#
#  conv1d_115 (Conv1D)         (None, 28, 128)           49280
#
#  batch_normalization_59 (Bat  (None, 28, 128)          512
# ...
